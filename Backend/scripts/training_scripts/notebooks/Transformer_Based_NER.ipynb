# %% [markdown]
# ### Custom NER - For Software Specefic Terms
# - Transformer based NER
# - Using Spacy & Bert Transformer

# %%
# Install necessary libraries
# !pip install -U spacy
# !pip install -U pip setuptools wheel

# %%
# Load spacy language model
# !python -m spacy download en_core_web_trf

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Check GPU Version
# !nvcc --version

# %%
# Install gup & transformer realted libraries
# !pip install torch==1.7.1+cu92 torchvision==0.8.2+cu92 torchaudio==0.7.2 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# !pip install spacy[gpu]
# !pip install spacy[transformers]

# %%
# Update spacy config file
# !python -m spacy init fill-config drive/MyDrive/Datasets/TheArchitect/base_config.cfg drive/MyDrive/Datasets/TheArchitect/config_spacy.cfg

# %%
# Verify model configurations
# !python -m spacy debug data drive/MyDrive/Datasets/TheArchitect/config_spacy.cfg

# %%
# Train model
# !python -m spacy train -g 0 drive/MyDrive/Datasets/TheArchitect/config_spacy.cfg --output ./

# %% [markdown]
# #### Evaluation

# %%
# Import libraries
import spacy

# %%
# load trained model
nlp = spacy.load("./model-best")

# %%
text = [
'''EG is an energy provider who allows their customers to access the service using web browsers and also from mobile devices.
   The online service will allow users to login to the system and submit the electricity and gas meter readings.
   EG will notify users on successful submission of meter readings also sends the bill amount based on the calculation.
'''
]

# %%
# Enities and labels
for doc in nlp.pipe(text, disable=["tagger", "parser"]):
    print([(ent.text, ent.label_) for ent in doc.ents])

# %%
# Zip and download model
# !zip -r /content/output_model.zip /content/model-best
